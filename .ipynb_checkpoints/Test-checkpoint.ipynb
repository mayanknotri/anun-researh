# %%
import pandas as pd
from openpyxl import load_workbook
from IPython.display import Image
from sklearn.preprocessing import Imputer
from sklearn import tree
from subprocess import check_call
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score
#mengimport library yg digunakan untuk load data excel dan library lainnya yg digunakan untuk proses clustering

# %%
import skfuzzy as fuzz
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
wb = load_workbook(filename = 'datafix.xlsx')
sheet_ranges = wb['Sheet1']

df = pd.DataFrame(sheet_ranges.values)
df
#load data excel yg akan digunakan untuk diclustering
# Out:
#              0            1         2              3   \
# 0           SNo  BookingDate        ID          STTNo
# 1     110459075  01-Mar-2018  JOG-1932  10-17-1617709
# 2     110459088  01-Mar-2018  JOG-1932  10-17-1617711
# 3     110459140  01-Mar-2018  JOG-1932  10-17-1617647
# 4     110459171  01-Mar-2018  JOG-1932   11-18-315622
# 5     110459198  01-Mar-2018  JOG-1932  10-17-1617708
# 6     110459247  01-Mar-2018  JOG-1932   11-18-315695
# 7     110459865  01-Mar-2018  JOG-1932   11-18-316262
# 8     110460042  01-Mar-2018  JOG-1932   11-18-316433
# 9     110461292  01-Mar-2018  JOG-1932  10-17-1618143
# 10    110462311  01-Mar-2018  JOG-1932  10-17-1617671
# 11    110462342  01-Mar-2018  JOG-1932   11-18-318558
# 12    110462345  01-Mar-2018  JOG-1932   11-18-318561
# 13    110462371  01-Mar-2018  JOG-1932   11-18-318582
# 14    110462399  01-Mar-2018  JOG-1932   11-18-318603
# 15    110462478  01-Mar-2018  JOG-1932   11-18-318673
# ...

# %%
d = df[1:4325][[0,6,8,9,10,11]]

d.columns = ['SNo','DestinationCity', 'Product', 'Gross', 'Volume', 'CommodityName']
d = d.dropna(axis=0, how='any')
d
#menentukan baris dan kolom yg digunakan dalam proses clustering
# Out:
#             SNo DestinationCity  Product Gross Volume  \
# 1     110459075       GORONTALO  REGPACK     7      3
# 2     110459088          GRESIK  REGPACK     1      1
# 3     110459140       MANOKWARI  REGPACK     2      1
# 4     110459171           AMBON  ONEPACK     1      1
# 5     110459198         KENDARI  REGPACK     1      1
# 6     110459247           BATAM  REGPACK     1      1
# 7     110459865          NABIRE  REGPACK     1      1
# 8     110460042  PANGKAL PINANG  REGPACK     1      1
# 9     110461292       SAMARINDA  REGPACK    22     17
# 10    110462311          NABIRE  REGPACK     4      2
# 11    110462342          LOMBOK  REGPACK     6      4
# 12    110462345          LOMBOK  REGPACK     5      2
# 13    110462371           JAMBI  REGPACK     2      1
# 14    110462399           JAMBI  REGPACK     3      1
# 15    110462478           BATAM  REGPACK     1      1
# 16    110462486           MEDAN  REGPACK     1      1
# ...

# %%
for index, row in d.iterrows():
    if row['Product']>='REGPACK':
        d.ix[index, 'PRODUCT'] = 1
    else:
        d.ix[index, 'PRODUCT'] = 2
        
d[['SNo','Product']]
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """
#             SNo  Product
# 1     110459075  REGPACK
# 2     110459088  REGPACK
# 3     110459140  REGPACK
# 4     110459171  ONEPACK
# 5     110459198  REGPACK
# 6     110459247  REGPACK
# 7     110459865  REGPACK
# 8     110460042  REGPACK
# 9     110461292  REGPACK
# ...

# %%
d
# Out:
#             SNo DestinationCity  Product Gross Volume  \
# 1     110459075       GORONTALO  REGPACK     7      3
# 2     110459088          GRESIK  REGPACK     1      1
# 3     110459140       MANOKWARI  REGPACK     2      1
# 4     110459171           AMBON  ONEPACK     1      1
# 5     110459198         KENDARI  REGPACK     1      1
# 6     110459247           BATAM  REGPACK     1      1
# 7     110459865          NABIRE  REGPACK     1      1
# 8     110460042  PANGKAL PINANG  REGPACK     1      1
# 9     110461292       SAMARINDA  REGPACK    22     17
# 10    110462311          NABIRE  REGPACK     4      2
# 11    110462342          LOMBOK  REGPACK     6      4
# 12    110462345          LOMBOK  REGPACK     5      2
# 13    110462371           JAMBI  REGPACK     2      1
# 14    110462399           JAMBI  REGPACK     3      1
# 15    110462478           BATAM  REGPACK     1      1
# 16    110462486           MEDAN  REGPACK     1      1
# ...

# %%
for index, row in d.iterrows():
    if row['CommodityName']>='ACCESSORIES':
        d.ix[index, 'COMMODITYNAME'] = 101
    elif row['CommodityName']>='BLOCK MACHINE':
        d.ix[index, 'COMMODITYNAME'] = 102
    elif row['CommodityName']>='BOOK / BUKU':
        d.ix[index, 'COMMODITYNAME'] = 103
    elif row['CommodityName']>='CANNED FOOD':
        d.ix[index, 'COMMODITYNAME'] = 104
    elif row['CommodityName']>='CD/DVD':
        d.ix[index, 'COMMODITYNAME'] = 105
    elif row['CommodityName']>='CETAKAN BROSUR STIKER UNDANGAN':
        d.ix[index, 'COMMODITYNAME'] = 106
    elif row['CommodityName']>='CLOTHING/GARMENT':
        d.ix[index, 'COMMODITYNAME'] = 107
    elif row['CommodityName']>='DOCUMENT':
        d.ix[index, 'COMMODITYNAME'] = 108
    elif row['CommodityName']>='DRIED FOOD':
        d.ix[index, 'COMMODITYNAME'] = 109
    elif row['CommodityName']>='ELECTRONIC SPARE PARTS':
        d.ix[index, 'COMMODITYNAME'] = 110
    elif row['CommodityName']>='FRUITS':
        d.ix[index, 'COMMODITYNAME'] = 111
    elif row['CommodityName']>='GENERAL OTHERS':
        d.ix[index, 'COMMODITYNAME'] = 112
    elif row['CommodityName']>='GLASSWARE':
        d.ix[index, 'COMMODITYNAME'] = 113
    elif row['CommodityName']>='HOME APPLIANCES':
        d.ix[index, 'COMMODITYNAME'] = 114
    elif row['CommodityName']>='LAPTOP':
        d.ix[index, 'COMMODITYNAME'] = 115
    elif row['CommodityName']>='MACHINE SPARE PARTS':
        d.ix[index, 'COMMODITYNAME'] = 116
    elif row['CommodityName']>='MEDICINE LIQUID':
        d.ix[index, 'COMMODITYNAME'] = 117
    elif row['CommodityName']>='MEDICINE NON LIQUID':
        d.ix[index, 'COMMODITYNAME'] = 118
    elif row['CommodityName']>='MUSICAL INSTRUMENT':
        d.ix[index, 'COMMODITYNAME'] = 119
    elif row['CommodityName']>='OTHER ELECTRONICS':
        d.ix[index, 'COMMODITYNAME'] = 120
    elif row['CommodityName']>='PACKAGE':
        d.ix[index, 'COMMODITYNAME'] = 121
    elif row['CommodityName']>='PERISHABLE DISHES/COOKING':
        d.ix[index, 'COMMODITYNAME'] = 122
    elif row['CommodityName']>='PRODUCT COSMETICS NON LIQUID':
        d.ix[index, 'COMMODITYNAME'] = 123
    elif row['CommodityName']>='SEED PLAN / TANAMAN POHON HIDUP':
        d.ix[index, 'COMMODITYNAME'] = 124
    elif row['CommodityName']>='VACCINE/SERUM':
        d.ix[index, 'COMMODITYNAME'] = 125
    else:
        d.ix[index, 'COMMODITYNAME'] = 126
        
d[['SNo','COMMODITYNAME']]
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until
#             SNo  COMMODITYNAME
# 1     110459075          101.0
# 2     110459088          101.0
# 3     110459140          101.0
# 4     110459171          101.0
# 5     110459198          101.0
# 6     110459247          101.0
# 7     110459865          101.0
# 8     110460042          101.0
# 9     110461292          101.0
# 10    110462311          101.0
# 11    110462342          101.0
# 12    110462345          101.0
# 13    110462371          101.0
# 14    110462399          101.0
# 15    110462478          101.0
# 16    110462486          101.0
# 17    110462529          101.0
# ...

# %%
d
# Out:
#             SNo DestinationCity  Product Gross Volume  \
# 1     110459075       GORONTALO  REGPACK     7      3
# 2     110459088          GRESIK  REGPACK     1      1
# 3     110459140       MANOKWARI  REGPACK     2      1
# 4     110459171           AMBON  ONEPACK     1      1
# 5     110459198         KENDARI  REGPACK     1      1
# 6     110459247           BATAM  REGPACK     1      1
# 7     110459865          NABIRE  REGPACK     1      1
# 8     110460042  PANGKAL PINANG  REGPACK     1      1
# 9     110461292       SAMARINDA  REGPACK    22     17
# 10    110462311          NABIRE  REGPACK     4      2
# 11    110462342          LOMBOK  REGPACK     6      4
# 12    110462345          LOMBOK  REGPACK     5      2
# 13    110462371           JAMBI  REGPACK     2      1
# 14    110462399           JAMBI  REGPACK     3      1
# 15    110462478           BATAM  REGPACK     1      1
# 16    110462486           MEDAN  REGPACK     1      1
# ...
