# %%
from __future__ import division, print_function
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import skfuzzy as fuzz
#mengimport library yg digunakan untuk load data excel dan library lainnya yg digunakan untuk proses clustering

# %%
dataset = pd.read_excel("datafix.xlsx")
dataset.head()
# Out:
#          SNo  BookingDate        ID          STTNo     Shipper  OriginCity  \
# 0  110459075  01-Mar-2018  JOG-1932  10-17-1617709         DEE  JOGJAKARTA
# 1  110459088  01-Mar-2018  JOG-1932  10-17-1617711         DEE  JOGJAKARTA
# 2  110459140  01-Mar-2018  JOG-1932  10-17-1617647   MEC ARTUR  JOGJAKARTA
# 3  110459171  01-Mar-2018  JOG-1932   11-18-315622      MELVIN  JOGJAKARTA
# 4  110459198  01-Mar-2018  JOG-1932  10-17-1617708  VINDY SHOP  JOGJAKARTA
#
#   DestinationCity  ForwardArea  Product  GrossWt  VolumeWt  \
# 0       GORONTALO          NaN  REGPACK        7         3
# 1          GRESIK          NaN  REGPACK        1         1
# 2       MANOKWARI          NaN  REGPACK        2         1
# 3           AMBON          NaN  ONEPACK        1         1
# 4         KENDARI          NaN  REGPACK        1         1
#
#                   CommodityName               LastTrackingStatus
# 0  PRODUCT COSMETICS NON LIQUID                 RECEIPT BY RIA .
# ...

# %%
df = dataset[['SNo', 'Product', 'GrossWt', 'VolumeWt']]
df = df.dropna(axis=0, how='any')
df.columns = ['SNo', 'Product', 'Gross', 'Volume']
df.head()
# Out:
#          SNo  Product  Gross  Volume
# 0  110459075  REGPACK      7       3
# 1  110459088  REGPACK      1       1
# 2  110459140  REGPACK      2       1
# 3  110459171  ONEPACK      1       1
# 4  110459198  REGPACK      1       1

# %%
df.loc[df['Product'] == 'REGPACK', 'Product'] = 2
df.loc[df['Product'] == 'ONEPACK', 'Product'] = 1
df.head()
# Out:
#          SNo  Product  Gross  Volume
# 0  110459075        2      7       3
# 1  110459088        2      1       1
# 2  110459140        2      2       1
# 3  110459171        1      1       1
# 4  110459198        2      1       1

# %%
sample = df.sample(400)
sample.head(10)
# Out:
#             SNo  Product  Gross  Volume
# 291   110551074        2      1       1
# 3626  111710341        2      3       2
# 1203  110831774        2     11       5
# 1086  110790512        2      9       7
# 587   110646918        1      1       1
# 4258  112037122        2      2       2
# 2704  111268574        2      1       1
# 1447  110892509        2      1       3
# 3531  111672859        2     20      35
# 574   110640509        2      1       1

# %%
proda = sample.loc[sample.Product == 1]
prodb = sample.loc[sample.Product == 2]

# %%
colors = ['b', 'orange', 'g', 'r', 'c', 'm', 'y', 'k', 'Brown', 'ForestGreen']

# Generate test data
np.random.seed(42)  # Set seed for reproducibility
apts = np.zeros(1)
bpts = np.zeros(1)
cpts = np.zeros(1)
dpts = np.zeros(1)
labels = np.zeros(1)

for i, x in sample.iterrows():
    apts = np.hstack((apts, np.random.standard_normal(100) * x['']))
# Out:
# SNo        110551074
# Product            2
# Gross              1
# Volume             1
# Name: 291, dtype: int64
# SNo        111710341
# Product            2
# Gross              3
# Volume             2
# Name: 3626, dtype: int64
# SNo        110831774
# Product            2
# Gross             11
# Volume             5
# Name: 1203, dtype: int64
# SNo        110790512
# Product            2
# Gross              9
# Volume             7
# Name: 1086, dtype: int64
# SNo        110646918
# Product            1
# Gross              1
# Volume             1
# Name: 587, dtype: int64
# SNo        112037122
# Product            2
# Gross              2
# Volume             2
# Name: 4258, dtype: int64
# SNo        111268574
# Product            2
# Gross              1
# Volume             1
# Name: 2704, dtype: int64
# SNo        110892509
# Product            2
# Gross              1
# Volume             3
# Name: 1447, dtype: int64
# SNo        111672859
# Product            2
# ...

# %%
set(dataset['DestinationCity'])
# Out:
# {'ALOR',
#  'AMBON',
#  'ASAHAN',
#  'BAJAWA',
#  'BALIKPAPAN',
#  'BANDA ACEH',
#  'BANDUNG',
#  'BANJARMASIN',
#  'BANYUWANGI',
#  'BATAM',
#  'BATANG',
#  'BAU BAU',
#  'BENGKULU',
#  'BERAU',
#  'BIMA',
#  'BINJAI',
#  'BITUNG',
#  'BLITAR',
#  'BOGOR',
#  'BULELENG',
#  'BULI',
#  'BULUKUMBA',
#  'CIANJUR',
#  'CIKARANG',
#  'CIREBON',
#  'DELI SERDANG',
#  'DENPASAR',
#  'DOBO',
#  'ENDE',
#  'FAK FAK',
#  'GORONTALO',
#  'GRESIK',
#  'GUNUNG SITOLI',
#  'INDRAMAYU',
#  'JAKARTA',
#  'JAMBI',
#  'JAYAPURA',
#  'JEMBER',
#  'JOGJAKARTA',
#  'KAIMANA',
#  'KENDARI',
#  'KOLAKA',
#  'KOTABARU',
#  'KUPANG',
#  'LABUAN BAJO',
#  'LABUHA',
#  'LAMONGAN',
#  'LAMPUNG',
#  'LARANTUKA',
#  'LOMBOK',
#  'LUBUK LINGGAU',
#  'LUWUK',
#  'MADIUN',
#  'MAGELANG',
#  'MAKASAR',
#  'MALANG',
#  'MAMUJU',
#  'MANADO',
#  'MANOKWARI',
#  'MAUMERE',
#  'MEDAN',
#  'MELONGUANE',
#  'MERAUKE',
#  'MEULABOH',
#  'MOJOKERTO',
#  'MOROTAI',
#  'NABIRE',
#  'NGAWI',
#  'PADANG',
#  'PALANGKARAYA',
# ...

# %%
len(set(dataset['DestinationCity']))
# Out:
# 112
