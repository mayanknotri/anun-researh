# %%
import pandas as pd
import numpy as np
import scipy.cluster.hierarchy as sch
from matplotlib import pyplot as plt
from sklearn.cluster import AgglomerativeClustering 
from openpyxl import load_workbook
from IPython.display import Image
from sklearn.preprocessing import Imputer
from sklearn import tree
from subprocess import check_call
import random as rd
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score

class CustomAHC(object):
    
    def __init__(self, filename, n_cluster = 4):
        self.dataset_raw = pd.read_excel(filename)
        self.dataset = self.dataset_raw[["BookingMonth", "DestinationCity", "Product", "GrossWt", "VolumeWt"]]
        self.dataset.columns = ["M01", "M02", "M03", "M04", "M05"]
        self.serial_numbers = [x for x in self.dataset_raw["SNo"]]
        self.n_cluster = n_cluster
        self.X = None
        self.labels = list()
    
    def transform(self):
        d = self.dataset.fillna(0)
        result = list()
        for i, row in d.iterrows():
            v1 = 0
            v2 = 0
            for x in range(1,3):
                v1 += row[f"M0{x}"]
            for x in range(4,6):
                v2 += row[f"M0{x}"]
            result.append([(v1 * (10 + rd.random()) / 2), (v2 * (10 + rd.random()) / 2)])
        self.X = pd.DataFrame(result).to_numpy()
        return self.X
    
    def get_cluster(self):
        model = AgglomerativeClustering(n_clusters=self.n_cluster, affinity='euclidean', linkage = 'single')
        model.fit(self.X)
        self.labels = model.labels_
        return model
    
    def plot(self):
        label = range(1, 11)
        plt.figure(figsize=(20, 10))
        plt.subplots_adjust(bottom=0.1)
        scatter = list()
        legends = list()
        for i in range(1, self.n_cluster):
            scatter.append(plt.scatter(self.X[self.labels == i, 0], self.X[self.labels == i, 1], s=30, label=str(i)))
            legends.append(f"Cluster {i}")
        plt.legend(scatter, legends, scatterpoints=1, loc="lower left", ncol=3, fontsize=20)
        plt.savefig("plot.png")
        return plt.show()
    
    def get_result(self):
        list_df = list()
        self.dataset_raw["Label"] = self.labels
        for i in range(self.n_cluster):
            df = self.dataset_raw[self.dataset_raw["Label"] == i]
            list_df.append(df)
        return list_df

# %%
data = CustomAHC(filename="datafix.xlsx")
X = data.transform()
X
# Out:
# array([[ 76.91747849,  50.94107034],
#        [191.71510526,  10.60633197],
#        [520.6419279 ,  15.39383628],
#        ...,
#        [405.09737558,  10.23012646],
#        [505.16151228,  10.25475632],
#        [100.59438409,  35.01267393]])

# %%
data.get_cluster()
# Out:
# AgglomerativeClustering(affinity='euclidean', compute_full_tree='auto',
#                         connectivity=None, distance_threshold=None,
#                         linkage='ward', memory=None, n_clusters=4,
#                         pooling_func='deprecated')

# %%
dendrogram = sch.dendrogram(sch.linkage(X, method="single"))
plt.savefig("dendrogram.png")

# %%
data.plot()

# %%
results = data.get_result()
results[0]
# Out:
#             SNo BookingDate  BookingMonth        ID          STTNo  \
# 2     110459140  2018-03-01             3  JOG-1932  10-17-1617647
# 3     110459171  2018-03-01             3  JOG-1932   11-18-315622
# 4     110459198  2018-03-01             3  JOG-1932  10-17-1617708
# 6     110459865  2018-03-01             3  JOG-1932   11-18-316262
# 9     110462311  2018-03-01             3  JOG-1932  10-17-1617671
# ...         ...         ...           ...       ...            ...
# 4312  112059642  2018-08-31             8  JOG-1932  11-18-1569410
# 4315  112059780  2018-08-31             8  JOG-1932  11-18-1569527
# 4319  112061999  2018-08-31             8  JOG-1932  11-18-1571389
# 4321  112062913  2018-08-31             8  JOG-1932  11-18-1572100
# 4322  112064013  2018-08-31             8  JOG-1932  11-18-1572732
#
#                  Shipper OriginCity  DestinationCity  ForwardArea  Product  \
# 2              MEC ARTUR      JOG31               92          NaN        2
# 3                 MELVIN      JOG31               81          NaN        1
# 4             VINDY SHOP      JOG31               74          NaN        2
# 6          EVIE SADDIYAH      JOG31               91          NaN        2
# 9         AYU MUSDALIFAH      JOG31               91          NaN        2
# ...                  ...        ...              ...          ...      ...
# 4312           RINI SHOP      JOG31               81          NaN        2
# 4315  NURHASANAH RENHARD      JOG31               91          NaN        2
# 4319        GABY TUAMAHU      JOG31               81          NaN        2
# 4321          ELA ARITIA      JOG31               72          NaN        2
# 4322                SONY      JOG31               91          NaN        2
#
#       GrossWt  VolumeWt                 CommodityName  \
# 2           2         1                   ACCESSORIES
# 3           1         1                   ACCESSORIES
# 4           1         1  PRODUCT COSMETICS NON LIQUID
# 6           1         1                   ACCESSORIES
# 9           4         2                    DRIED FOOD
# ...       ...       ...                           ...
# 4312        1         1              CLOTHING/GARMENT
# 4315        1         1              CLOTHING/GARMENT
# 4319        5         4              CLOTHING/GARMENT
# 4321        1         1              CLOTHING/GARMENT
# 4322        1         1              CLOTHING/GARMENT
#
#                    LastTrackingStatus  Label
# 2            RECEIPT BY ANDRY TRIAS .      0
# 3     RECEIPT BY SANCHIA AHULUHELUW .      0
# 4                  RECEIPT BY HESTI .      0
# 6                RECEIPT BY JUMAINI .      0
# 9              RECEIPT BY LIA ERIKA .      0
# ...                               ...    ...
# 4312     RECEIPT BY VIANTRYY REYAAN .      0
# 4315              RECEIPT BY ZUHROH .      0
# 4319             RECEIPT BY RIZAL T .      0
# 4321          RECEIPT BY FITRIAWATI .      0
# 4322         RECEIPT BY FEBRIAN P W .      0
#
# [1920 rows x 15 columns]

# %%
results[1]
# Out:
#             SNo BookingDate  BookingMonth        ID          STTNo  \
# 0     110459075  2018-03-01             3  JOG-1932  10-17-1617709
# 1     110459088  2018-03-01             3  JOG-1932  10-17-1617711
# 5     110459247  2018-03-01             3  JOG-1932   11-18-315695
# 7     110460042  2018-03-01             3  JOG-1932   11-18-316433
# 12    110462371  2018-03-01             3  JOG-1932   11-18-318582
# ...         ...         ...           ...       ...            ...
# 4300  112056183  2018-08-31             8  JOG-1932  11-18-1566529
# 4301  112056223  2018-08-31             8  JOG-1932  11-18-1566563
# 4314  112059705  2018-08-31             8  JOG-1932  11-18-1569468
# 4317  112061510  2018-08-31             8  JOG-1932  10-17-1618751
# 4323  112064220  2018-08-31             8  JOG-1932  10-17-1618770
#
#                Shipper OriginCity  DestinationCity  ForwardArea  Product  \
# 0                  DEE      JOG31               12          NaN        2
# 1                  DEE      JOG31               35          NaN        2
# 5                  DEE      JOG31               21          NaN        2
# 7        RIRIN AFRIANI      JOG31               19          NaN        2
# 12          CLEVHOSHOP      JOG31               15          NaN        2
# ...                ...        ...              ...          ...      ...
# 4300      COBRA DENTAL      JOG31               11          NaN        2
# 4301      COBRA DENTAL      JOG31               14          NaN        2
# 4314  CLEVHOSHOP JOGJA      JOG31               15          NaN        2
# 4317    HERMAN KISWARA      JOG31               13          NaN        2
# 4323           YULIANA      JOG31               12          NaN        1
#
#       GrossWt  VolumeWt                 CommodityName  \
# 0           7         3  PRODUCT COSMETICS NON LIQUID
# 1           1         1  PRODUCT COSMETICS NON LIQUID
# 5           1         1  PRODUCT COSMETICS NON LIQUID
# 7           1         1  PRODUCT COSMETICS NON LIQUID
# 12          2         1              CLOTHING/GARMENT
# ...       ...       ...                           ...
# 4300        3         3                   ACCESSORIES
# 4301        6         4                   ACCESSORIES
# 4314        2         1              CLOTHING/GARMENT
# 4317        7         8                   ACCESSORIES
# 4323        5         2                    DRIED FOOD
#
#                                      LastTrackingStatus  Label
# 0                                      RECEIPT BY RIA .      1
# 1                                   RECEIPT BY NURFAN .      1
# 5                                RECEIPT BY IBU WIWIT .      1
# 7                                    RECEIPT BY ARIEL .      1
# 12                                    RECEIPT BY ANDI .      1
# ...                                                 ...    ...
# 4300                          RECEIPT BY COBRA DENTAL .      1
# 4301                             RECEIPT BY EKA MONKA .      1
# 4314                                  RECEIPT BY DEDI .      1
# 4317  [eCargo No. 990-94378491 ] STI AT JASA SURYA, ...      1
# 4323                        RECEIPT BY MUS (TETANGGA) .      1
#
# [1030 rows x 15 columns]

# %%
from sklearn import metrics

# %%
print("Silhouette Coefficient: %0.3f"
      % metrics.silhouette_score(data.X, data.labels, metric='euclidean'))
# Out:
# Silhouette Coefficient: 0.563
