# %%
from  openpyxl import load_workbook 
import pandas as pd

# %%
wb = load_workbook(filename = 'penumpangtransjogja.xlsx') 
sheet_ranges = wb['Sheet1']

df = pd.DataFrame(sheet_ranges.values)
df
# Out:
#                 0         1            2           3       4       5
# 0           Halte  Kode bus          Jam  jml di bus  masuk   keluar
# 1          Musper      1B.1  05.00-06.00           0       0       0
# 2          Musper      1B.2  06.00-07.00           9       0       3
# 3          Musper      1B.3  07.00-08.00           7       0       4
# 4          Musper      1B.4  08.00-09.00          20       3      14
# 5          Musper      1B.5  09.00-10.00          49       9      30
# 6   Condong catur      1B.6  10.00-11.00         117      12      82
# 7       Binamarga      1B.7  11.00-12.00          72      38      80
# 8             JEC      1B.8  12.00-13.00         120      69      37
# 9       Malioboro      1B.9  13.00-14.00          35       0       0
# 10         Musper     1B.10  14.00-15.00           0       0       0
# 11         Musper     1B.11  15.00-16.00           0       0       0
# 12  Condong catur     1B.12  16.00-17.00           0       0       0
# ...

# %%
d = df[1:16] [[0,1,2,3,4,5]] 

d.columns = ['Halte','Kode Bus','Jam','Jml dibus','masuk','Keluar']
d
# Out:
#             Halte Kode Bus          Jam Jml dibus masuk Keluar
# 1          Musper     1B.1  05.00-06.00         0     0      0
# 2          Musper     1B.2  06.00-07.00         9     0      3
# 3          Musper     1B.3  07.00-08.00         7     0      4
# 4          Musper     1B.4  08.00-09.00        20     3     14
# 5          Musper     1B.5  09.00-10.00        49     9     30
# 6   Condong catur     1B.6  10.00-11.00       117    12     82
# 7       Binamarga     1B.7  11.00-12.00        72    38     80
# 8             JEC     1B.8  12.00-13.00       120    69     37
# 9       Malioboro     1B.9  13.00-14.00        35     0      0
# 10         Musper    1B.10  14.00-15.00         0     0      0
# 11         Musper    1B.11  15.00-16.00         0     0      0
# 12  Condong catur    1B.12  16.00-17.00         0     0      0
# 13      Binamarga    1B.13  17.00-18.00         0     0      0
# 14            JEC    1B.14  18.00-19.00         0     0      0
# ...

# %%
d[['Halte']]
# Out:
#             Halte
# 1          Musper
# 2          Musper
# 3          Musper
# 4          Musper
# 5          Musper
# 6   Condong catur
# 7       Binamarga
# 8             JEC
# 9       Malioboro
# 10         Musper
# 11         Musper
# 12  Condong catur
# 13      Binamarga
# 14            JEC
# 15         Musper

# %%
d[:16]
# Out:
#             Halte Kode Bus          Jam Jml dibus masuk Keluar
# 1          Musper     1B.1  05.00-06.00         0     0      0
# 2          Musper     1B.2  06.00-07.00         9     0      3
# 3          Musper     1B.3  07.00-08.00         7     0      4
# 4          Musper     1B.4  08.00-09.00        20     3     14
# 5          Musper     1B.5  09.00-10.00        49     9     30
# 6   Condong catur     1B.6  10.00-11.00       117    12     82
# 7       Binamarga     1B.7  11.00-12.00        72    38     80
# 8             JEC     1B.8  12.00-13.00       120    69     37
# 9       Malioboro     1B.9  13.00-14.00        35     0      0
# 10         Musper    1B.10  14.00-15.00         0     0      0
# 11         Musper    1B.11  15.00-16.00         0     0      0
# 12  Condong catur    1B.12  16.00-17.00         0     0      0
# 13      Binamarga    1B.13  17.00-18.00         0     0      0
# 14            JEC    1B.14  18.00-19.00         0     0      0
# ...

# %%
d[['Kode Bus']] [:10]
# Out:
#    Kode Bus
# 1      1B.1
# 2      1B.2
# 3      1B.3
# 4      1B.4
# 5      1B.5
# 6      1B.6
# 7      1B.7
# 8      1B.8
# 9      1B.9
# 10    1B.10

# %%
d.sort_values(['Halte'], ascending=[0])[:10]
# Out:
#         Halte Kode Bus          Jam Jml dibus masuk Keluar
# 1      Musper     1B.1  05.00-06.00         0     0      0
# 2      Musper     1B.2  06.00-07.00         9     0      3
# 3      Musper     1B.3  07.00-08.00         7     0      4
# 4      Musper     1B.4  08.00-09.00        20     3     14
# 5      Musper     1B.5  09.00-10.00        49     9     30
# 10     Musper    1B.10  14.00-15.00         0     0      0
# 11     Musper    1B.11  15.00-16.00         0     0      0
# 15     Musper    1B.15  19.00-20.00         0     0      0
# 9   Malioboro     1B.9  13.00-14.00        35     0      0
# 8         JEC     1B.8  12.00-13.00       120    69     37
