# %%
from openpyxl import load_workbook
import pandas as pd

from sklearn import preprocessing as pre #untuk proses preprocessing
from sklearn.svm import SVR        #untuk import metode SVR (forecasting)
from sklearn.metrics import mean_squared_error   #library untuk metode pengujian

# %%
wb = load_workbook(filename='Data Alumni.xlsx')
sheet = wb['Sheet1']
data = pd.DataFrame (sheet.values)
data
# Out:
#              0         1                     2   \
# 0   DATA ALUMNI      None                  None
# 1          None      None                  None
# 2            No       Nim                 Nama
# 3          None      None                  None
# 4             1   9018263      Puguh Drajat E.P
# 5             2  12022030  Arsyad Cahya Subrata
# 6             3  12020021          Yesi Novela
# 7             4   9018269       Pandu Herwijaya
# 8             5   9018109        Anjar Prasetyo
# 9             6   9020026   Moh. Dadi Kurniawan
# 10            7  12018060        Martin Sarlina
# 11            8  11018022      Yan Adhi Permadi
# 12            9   9018212       Achicha Wahyuni
# 13           10   9018301   Yayan Tisna Permadi
# 14           11  12022020        Muh. Rama dhai
# 15           12  12022038           Nurwahyuddi
# 16           13  12019039          Agus Purnomo
# 17           14  11018111  M. Akhwan Zulfayandi
# ...

# %%
d = data[4:20][[12,6,7]]

d.columns = ['IPK','TAHUN MASUK','TAHUN LULUS']
d = d.dropna(axis=0, how='any')
d
# Out:
#      IPK TAHUN MASUK TAHUN LULUS
# 4   2,13        2009        2016
# 7   2,75        2009        2016
# 9   3,24        2009        2016
# 10  3,27        2012        2016
# 11  3,20        2011        2016
# 12  3,24        2009        2016
# 13  3,06        2009        2016
# 14  3.47        2012        2016
# 15  3,62        2012        2016
# 16  3,32        2012        2016
# 17  3,14        2011        2016
# 18  2,99        2009        2016
# 19  3,60        2012        2016

# %%
p = d.dropna() #cleaning data
p
# Out:
#      IPK TAHUN MASUK TAHUN LULUS
# 4   2,13        2009        2016
# 7   2,75        2009        2016
# 9   3,24        2009        2016
# 10  3,27        2012        2016
# 11  3,20        2011        2016
# 12  3,24        2009        2016
# 13  3,06        2009        2016
# 14  3.47        2012        2016
# 15  3,62        2012        2016
# 16  3,32        2012        2016
# 17  3,14        2011        2016
# 18  2,99        2009        2016
# 19  3,60        2012        2016

# %%
for index, row in p.iterrows():
    p.ix[index, 'MASA STUDI'] = row['TAHUN LULUS'] - row['TAHUN MASUK']

p['IPK'] = p['IPK'].apply(str)
p['IPK'] = p['IPK'].str.replace(',','.').apply(float)

print(p.dtypes)
# Out:
# IPK            float64
# TAHUN MASUK     object
# TAHUN LULUS     object
# MASA STUDI     float64
# dtype: object
# C:\Users\User\Anaconda2\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
training = p.reset_index(drop=True)
training
# Out:
#      IPK TAHUN MASUK TAHUN LULUS  MASA STUDI
# 0   2.13        2009        2016         7.0
# 1   2.75        2009        2016         7.0
# 2   3.24        2009        2016         7.0
# 3   3.27        2012        2016         4.0
# 4   3.20        2011        2016         5.0
# 5   3.24        2009        2016         7.0
# 6   3.06        2009        2016         7.0
# 7   3.47        2012        2016         4.0
# 8   3.62        2012        2016         4.0
# 9   3.32        2012        2016         4.0
# 10  3.14        2011        2016         5.0
# 11  2.99        2009        2016         7.0
# 12  3.60        2012        2016         4.0

# %%
label = training['MASA STUDI'].values
label
# Out:
# array([7., 7., 7., 4., 5., 7., 7., 4., 4., 4., 5., 7., 4.])

# %%
feature = training[['IPK']].values
feature
# Out:
# array([[2.13],
#        [2.75],
#        [3.24],
#        [3.27],
#        [3.2 ],
#        [3.24],
#        [3.06],
#        [3.47],
#        [3.62],
#        [3.32],
#        [3.14],
#        [2.99],
#        [3.6 ]])

# %%
SVR_model = SVR(kernel='precomputed',ted().fit(feature)
x = scaler.transform(feature)
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fe0d32156b9b> in <module>()
# ----> 1 scaler = pre.Computed().fit(feature)
#       2 x = scaler.transform(feature)
#       3 x
#
# NameError: name 'pre' is not defined

# %%
import numpy as np
from sklearn import svm
X = np.array([[0, 0], [1, 1]])
y = [0, 1]
clf = svm.SVC(kernel='precomputed')
# linear kernel computation
gram = np.dot(X, X.T)
clf.fit(gram, y)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto',
#   kernel='precomputed', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
testing = training.sample(n=13)
testing
# Out:
#      IPK TAHUN MASUK TAHUN LULUS  MASA STUDI
# 3   3.27        2012        2016         4.0
# 0   2.13        2009        2016         7.0
# 11  2.99        2009        2016         7.0
# 5   3.24        2009        2016         7.0
# 8   3.62        2012        2016         4.0
# 7   3.47        2012        2016         4.0
# 4   3.20        2011        2016         5.0
# 12  3.60        2012        2016         4.0
# 10  3.14        2011        2016         5.0
# 2   3.24        2009        2016         7.0
# 6   3.06        2009        2016         7.0
# 1   2.75        2009        2016         7.0
# 9   3.32        2012        2016         4.0

# %%
feature_test = testing[list(['IPK'])].values
feature_test
# Out:
# array([[3.27],
#        [2.13],
#        [2.99],
#        [3.24],
#        [3.62],
#        [3.47],
#        [3.2 ],
#        [3.6 ],
#        [3.14],
#        [3.24],
#        [3.06],
#        [2.75],
#        [3.32]])

# %%
scaler_test = pre.StandardScaler().fit(feature_test)
test = scaler_test.transform(feature_test)
test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2b94f59581c2> in <module>()
# ----> 1 scaler_test = pre.Computed().fit(feature_test)
#       2 test = scaler_test.transform(feature_test)
#       3 test
#
# NameError: name 'pre' is not defined

# %%
y_pred = SVR_model.predict(test)
y_pred
# Out:
# array([5.09999993, 5.10005405, 5.10000023, 5.09999997, 5.09999501,
#        5.09999846, 5.1       , 5.09999563, 5.1       , 5.09999997,
#        5.10000005, 5.10000335, 5.09999978])

# %% [markdown]
# # pengujian MSE

# %%
y_true = testing['MASA STUDI'].values
y_true
# Out:
# array([4., 7., 7., 7., 4., 4., 5., 4., 5., 7., 7., 7., 4.])

# %%
mean_squared_error(y_true,y_pred)
# Out:
# 2.1330581855780717
