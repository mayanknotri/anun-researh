# %%
from  openpyxl import load_workbook #mengolah data excel
import pandas as pd #mengolah data

# %%
wb = load_workbook(filename = 'Data Alumni.xlsx') #inisialisasi file excel yg akan di import
sheet_ranges = wb['Sheet5']

df = pd.DataFrame(sheet_ranges.values)
df
# Out:
#     0         1                     2                                 3   \
# 0   No       Nim                 Nama             Tempat & tanggal lahir
# 1    1   9018263      Puguh Drajat E.P        Purworejo, 4 November 1989
# 2    2  12022030  Arsyad Cahya Subrata              Bantul, 21 juni 1994
# 3    3  12020021          Yesi Novela          Tempilang, 1 januari 1995
# 4    4   9018269       Pandu Herwijaya         Lampung, 19 Desember 1990
# 5    5   9018109        Anjar Prasetyo        Gunungkidul, 27 April 1991
# 6    6   9020026   Moh. Dadi Kurniawan         Savanajaya, 27 Maret 1992
# 7    7  12018060        Martin Sarlina              Lepak, 23 Maret 1994
# 8    8  11018022      Yan Adhi Permadi              Jepara, 22 juni 1993
# 9    9   9018212       Achicha Wahyuni           Yogyakarta, 3 juni 1991
# 10  10   9018301   Yayan Tisna Permadi      Purbalingga, 08 Oktober 1991
# 11  11  12022020        Muh. Rama dhai          Pekanbaru, 29 Maret 1992
# ...

# %%
d = df[1:12] [[1,3,12,9,6,7,10,11]] #setting ke dalam template

d.columns = ['NIM','TTL','IPK','lama tunggu','masuk','lulus','gaji','TOEFL']
d
# Out:
#          NIM                           TTL   IPK lama tunggu masuk lulus  \
# 1    9018263    Purworejo, 4 November 1989  2,13         2.4  2009  2016
# 2   12022030          Bantul, 21 juni 1994  None        None  2012  2016
# 3   12020021     Tempilang, 1 januari 1995  None         2.4  2012  2016
# 4    9018269     Lampung, 19 Desember 1990  2,75         2.4  2009  2016
# 5    9018109    Gunungkidul, 27 April 1991  None        None  2009  2016
# 6    9020026     Savanajaya, 27 Maret 1992  3,24         2.4  2009  2016
# 7   12018060          Lepak, 23 Maret 1994  3,27         2.4  2012  2016
# 8   11018022          Jepara, 22 juni 1993  3,20         2.4  2011  2016
# 9    9018212       Yogyakarta, 3 juni 1991  3,24           0  2009  2016
# 10   9018301  Purbalingga, 08 Oktober 1991  3,06         2.4  2009  2016
# 11  12022020      Pekanbaru, 29 Maret 1992  3.47         2.4  2012  2016
#
#            gaji TOEFL
# 1   1.47563e+06   390
# 2          None  None
# ...

# %%
d.sort_values(['TTL'], ascending=[1]) #mengurutkan data secara ascending ata descending berdasarkan kolom TTL
# Out:
#          NIM                           TTL   IPK lama tunggu masuk lulus  \
# 2   12022030          Bantul, 21 juni 1994  None        None  2012  2016
# 5    9018109    Gunungkidul, 27 April 1991  None        None  2009  2016
# 8   11018022          Jepara, 22 juni 1993  3,20         2.4  2011  2016
# 4    9018269     Lampung, 19 Desember 1990  2,75         2.4  2009  2016
# 7   12018060          Lepak, 23 Maret 1994  3,27         2.4  2012  2016
# 11  12022020      Pekanbaru, 29 Maret 1992  3.47         2.4  2012  2016
# 10   9018301  Purbalingga, 08 Oktober 1991  3,06         2.4  2009  2016
# 1    9018263    Purworejo, 4 November 1989  2,13         2.4  2009  2016
# 6    9020026     Savanajaya, 27 Maret 1992  3,24         2.4  2009  2016
# 3   12020021     Tempilang, 1 januari 1995  None         2.4  2012  2016
# 9    9018212       Yogyakarta, 3 juni 1991  3,24           0  2009  2016
#
#            gaji TOEFL
# 2          None  None
# 5          None  None
# ...

# %%
d.sort_values(['masuk'], ascending=[1]) #mengurutkan data secara ascending ata descending berdasarkan kolom TTL
# Out:
#          NIM                           TTL   IPK lama tunggu masuk lulus  \
# 1    9018263    Purworejo, 4 November 1989  2,13         2.4  2009  2016
# 4    9018269     Lampung, 19 Desember 1990  2,75         2.4  2009  2016
# 5    9018109    Gunungkidul, 27 April 1991  None        None  2009  2016
# 6    9020026     Savanajaya, 27 Maret 1992  3,24         2.4  2009  2016
# 9    9018212       Yogyakarta, 3 juni 1991  3,24           0  2009  2016
# 10   9018301  Purbalingga, 08 Oktober 1991  3,06         2.4  2009  2016
# 8   11018022          Jepara, 22 juni 1993  3,20         2.4  2011  2016
# 2   12022030          Bantul, 21 juni 1994  None        None  2012  2016
# 3   12020021     Tempilang, 1 januari 1995  None         2.4  2012  2016
# 7   12018060          Lepak, 23 Maret 1994  3,27         2.4  2012  2016
# 11  12022020      Pekanbaru, 29 Maret 1992  3.47         2.4  2012  2016
#
#            gaji TOEFL
# 1   1.47563e+06   390
# 4       1475634   413
# ...

# %%
d['TTL'] #menampilkan data pada kolom TTL
# Out:
# 1       Purworejo, 4 November 1989
# 2             Bantul, 21 juni 1994
# 3        Tempilang, 1 januari 1995
# 4        Lampung, 19 Desember 1990
# 5       Gunungkidul, 27 April 1991
# 6        Savanajaya, 27 Maret 1992
# 7             Lepak, 23 Maret 1994
# 8             Jepara, 22 juni 1993
# 9          Yogyakarta, 3 juni 1991
# 10    Purbalingga, 08 Oktober 1991
# 11        Pekanbaru, 29 Maret 1992
# Name: TTL, dtype: object

# %%
d[['TTL']] #dengan bentuk tabel
# Out:
#                              TTL
# 1     Purworejo, 4 November 1989
# 2           Bantul, 21 juni 1994
# 3      Tempilang, 1 januari 1995
# 4      Lampung, 19 Desember 1990
# 5     Gunungkidul, 27 April 1991
# 6      Savanajaya, 27 Maret 1992
# 7           Lepak, 23 Maret 1994
# 8           Jepara, 22 juni 1993
# 9        Yogyakarta, 3 juni 1991
# 10  Purbalingga, 08 Oktober 1991
# 11      Pekanbaru, 29 Maret 1992

# %%
d[:5] #menampilkan data dengan jumlah tertentu
# Out:
#         NIM                         TTL   IPK lama tunggu masuk lulus  \
# 1   9018263  Purworejo, 4 November 1989  2,13         2.4  2009  2016
# 2  12022030        Bantul, 21 juni 1994  None        None  2012  2016
# 3  12020021   Tempilang, 1 januari 1995  None         2.4  2012  2016
# 4   9018269   Lampung, 19 Desember 1990  2,75         2.4  2009  2016
# 5   9018109  Gunungkidul, 27 April 1991  None        None  2009  2016
#
#           gaji TOEFL
# 1  1.47563e+06   390
# 2         None  None
# 3  1.47563e+06  None
# 4      1475634   413
# 5         None  None

# %% [markdown]
# ## praktikum 2

# %%
d = d.dropna(axis=0, how='any')
d
# Out:
#          NIM                           TTL   IPK lama tunggu masuk lulus  \
# 1    9018263    Purworejo, 4 November 1989  2,13         2.4  2009  2016
# 4    9018269     Lampung, 19 Desember 1990  2,75         2.4  2009  2016
# 6    9020026     Savanajaya, 27 Maret 1992  3,24         2.4  2009  2016
# 7   12018060          Lepak, 23 Maret 1994  3,27         2.4  2012  2016
# 8   11018022          Jepara, 22 juni 1993  3,20         2.4  2011  2016
# 9    9018212       Yogyakarta, 3 juni 1991  3,24           0  2009  2016
# 10   9018301  Purbalingga, 08 Oktober 1991  3,06         2.4  2009  2016
# 11  12022020      Pekanbaru, 29 Maret 1992  3.47         2.4  2012  2016
#
#            gaji TOEFL
# 1   1.47563e+06   390
# 4       1475634   413
# 6   1.47563e+06   400
# 7   1.47563e+06   396
# 8   1.47563e+06   460
# 9        600000   403
# 10  1.47563e+06   450
# 11      1200000   423

# %%
x = df[1:12] [[1,3,12,9,6,7,10,11]] #setting ke dalam template

x.columns = ['NIM','TTL','IPK','lama tunggu','masuk','lulus','gaji','TOEFL']
x
# Out:
#          NIM                           TTL   IPK lama tunggu masuk lulus  \
# 1    9018263    Purworejo, 4 November 1989  2,13         2.4  2009  2016
# 2   12022030          Bantul, 21 juni 1994  None        None  2012  2016
# 3   12020021     Tempilang, 1 januari 1995  None         2.4  2012  2016
# 4    9018269     Lampung, 19 Desember 1990  2,75         2.4  2009  2016
# 5    9018109    Gunungkidul, 27 April 1991  None        None  2009  2016
# 6    9020026     Savanajaya, 27 Maret 1992  3,24         2.4  2009  2016
# 7   12018060          Lepak, 23 Maret 1994  3,27         2.4  2012  2016
# 8   11018022          Jepara, 22 juni 1993  3,20         2.4  2011  2016
# 9    9018212       Yogyakarta, 3 juni 1991  3,24           0  2009  2016
# 10   9018301  Purbalingga, 08 Oktober 1991  3,06         2.4  2009  2016
# 11  12022020      Pekanbaru, 29 Maret 1992  3.47         2.4  2012  2016
#
#            gaji TOEFL
# 1   1.47563e+06   390
# 2          None  None
# ...

# %%
a = x[['lama tunggu']]
a
# Out:
#    lama tunggu
# 1          2.4
# 2         None
# 3          2.4
# 4          2.4
# 5         None
# 6          2.4
# 7          2.4
# 8          2.4
# 9            0
# 10         2.4
# 11         2.4

# %%
for column in a:
    rata = a.loc[:, column].mean()  #cari rata-rata
    a.loc[:, column].fillna (rata, inplace=True)

a
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\generic.py:3295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
#     lama tunggu
# 1      2.400000
# 2      2.133333
# 3      2.400000
# 4      2.400000
# 5      2.133333
# 6      2.400000
# 7      2.400000
# 8      2.400000
# 9      0.000000
# 10     2.400000
# 11     2.400000
